# %%
import pandas as pd
import matplotlib.pyplot as plt 
import os

# %%
data_dir = os.path.join("..","data")
train_dir = os.path.join(data_dir,"train")
test_dir = os.path.join(data_dir,"test")

train_files = os.listdir(train_dir)

# %%
app_usage = pd.read_csv(os.path.join(train_dir, "app_usage.csv"))
app_usage.head()
# Out:
# ['app_usage.csv', 'churn_labels.csv', 'claims.csv', 'web_visits.csv']

# %%
churn_labels = pd.read_csv(os.path.join(train_dir, "churn_labels.csv"))
churn_labels.head()

# %%
claims = pd.read_csv(os.path.join(train_dir, "claims.csv"))
claims.head()

# %%
claims = pd.read_csv(os.path.join(train_dir, "claims.csv"))
claims.head()
